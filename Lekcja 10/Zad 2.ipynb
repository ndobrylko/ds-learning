# %% [markdown]
# Masz dwie tablice reprezentujące ceny produktów przed i po rabacie:
#
# before = np.array([100, 250, 75, 320, 180, 450, 90])
# after = np.array([80, 200, 60, 280, 150, 400, 75])
#
# Oblicz i wypisz:
# Różnicę między cenami (oszczędności)
# Procent rabatu dla każdego produktu
# Średnią oszczędność
#
# Wymagania:
# Użyj operacji wektorowych (bez pętli)
# Wynik zaokrąglij do 2 miejsc po przecinku

# %%
import numpy as np

before = np.array([100, 250, 75, 320, 180, 450, 90])
after = np.array([80, 200, 60, 280, 150, 400, 75])

oszczednosci = before - after
procent_rabatu = (oszczednosci / before) * 100
srednia_oszczednosc = np.mean(oszczednosci)

#zaokraglenie
oszczednosci = np.round(oszczednosci,2)
procent_rabatu = np.round(procent_rabatu,2)
srednia_oszczednosc = np.round(srednia_oszczednosc, 2)

print("oszczednosci:", oszczednosci)
print("% rabatu:", procent_rabatu)
print("srednia oszczednosc:", srednia_oszczednosc)
# Out:
# oszczednosci: [20 50 15 40 30 50 15]
# % rabatu: [20.   20.   20.   12.5  16.67 11.11 16.67]
# srednia oszczednosc: 31.43
