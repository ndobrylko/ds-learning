# %% [markdown]
# Dana tablica: arr = np.arange(1, 13) Wykonaj: <br>
# Zmień kształt na (3, 4)
# Zmień kształt na (2, 6)
# Zmień kształt na (4, 3)
# Spłaszcz z powrotem do 1D (flatten lub ravel) Wymagania:
# Użyj metody .reshape()
# Sprawdź różnicę między flatten() a ravel()
