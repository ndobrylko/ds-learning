# %%
waga = 70
wzrost = 1.75
bmi = waga / (wzrost ** 2)
print(f"BMI: {bmi:.2f}")
if bmi <18.5:
    interpretacja = "Niedowaga"
elif bmi < 25:
    interpretacja = "Norma"
else:
    interpretacja = "Nadwaga"
print(f"Interpretacja: {interpretacja}")
# Out:
# BMI: 22.86
# Interpretacja: Norma
