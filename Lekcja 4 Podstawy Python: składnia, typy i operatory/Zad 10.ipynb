# %%
model_name = "XGBoost Classifier"
dataset = "Credit Card Fraud"
n_samples = 284807
accuracy = 0.9991
precision = 0.8876
recall = 0.7561

f1_score = 2 * (precision * recall) / (precision + recall)

line = "="*50
print(line)
print(f"{'MODEL REPORT':^50}")
print(line)
print(f"{'Model':<15}: {model_name}")
print(f"{'Dataset':<15}: {dataset}")
print(f"{'Number of samples':<15}: {n_samples:,}")
print(line)
print(f"{'Metric':<12} | {'Value':>10}")
print("-"*50)
print(f"{'Accuracy':<12} | {accuracy:.2%}")
print(f"{'Precision':<12} | {precision:.2%}")
print(f"{'Recall':<12} | {recall:.2%}")
print(f"{'F1-Score':<12} | {f1_score:.2%}")
print(line)
# Out:
# ...
#                    MODEL REPORT
# ...
# Model          : XGBoost Classifier
# Dataset        : Credit Card Fraud
# Number of samples: 284,807
# ...
# Metric       |      Value
# --------------------------------------------------
# Accuracy     | 99.91%
# Precision    | 88.76%
# Recall       | 75.61%
# F1-Score     | 81.66%
# ...
