# %%
calosc = 1000

train = calosc * 70 // 100
val = calosc * 15 // 100
test = calosc - train - val

print(f"Zbiór treningowy: {train}")
print(f"Zbiór walidacyjny: {val}")
print(f"Zbiór testowy: {test}")
print(f"Suma: {train + val + test}")
# Out:
# Zbiór treningowy: 700
# Zbiór walidacyjny: 150
# Zbiór testowy: 150
# Suma: 1000
