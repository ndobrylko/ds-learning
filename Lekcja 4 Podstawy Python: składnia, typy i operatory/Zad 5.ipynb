# %%
path = "data/processed/train_fold_03_normalized.csv"
parts = path.split("/")
print(parts)
# Out:
# ['data', 'processed', 'train_fold_03_normalized.csv']

# %%
folder = parts[1]
filename_parts = parts[2].split("_")
typ_zbioru = filename_parts[0]
numer_fold = filename_parts[2]
file_format = filename_parts[3].split(".")[1]

print("Folder:", folder)
print("Typ zbioru:", typ_zbioru)
print("Numer fold:", numer_fold)
print("Format pliku:", file_format)
# Out:
# Folder: processed
# Typ zbioru: train
# Numer fold: 03
# Format pliku: csv
