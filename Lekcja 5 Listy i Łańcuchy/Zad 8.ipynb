# %% [markdown]
# Masz nazwę pliku: "model_results_2024_Q3.csv" . Wyciągnij rok i kwartał używając
# slicing lub split.

# %%
filename = "model_results_2024_Q3.csv"
components = filename.split('_')
components[3] = components[3].replace('.csv', '')
print(components)
print(f"""Rok: {components[2]}
Kwartał: {components[3]}""")
# Out:
# ['model', 'results', '2024', 'Q3']
# Rok: 2024
# Kwartał: Q3

# %%
#Rozwiązanie przy użyciu SLICING
filename = "model_results_2024_Q3.csv"

rok = filename[14:18]       # znaki od 14 do 17 (rok)
kwartal = filename[19:21]   # znaki od 19 do 20 (Q3)
print(rok, kwartal)
# Out:
# 2024 Q3
