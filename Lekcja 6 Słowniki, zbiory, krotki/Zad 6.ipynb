# %% [markdown]
# Stwórz krotkę z danymi studenta: (imię, nazwisko, wiek, średnia_ocen) . Użyj tuple
# unpacking by przypisać każdy element do osobnej zmiennej i wypisz informacje.
# Wymagania:
# (proste)
# Stwórz krotkę z przykładowymi danymi
# Użyj unpacking
# Wypisz sformatowany wynik

# %%
student = ('Jan', 'Kowalski', 29, 4.5)
#unpacking (działa tylko jesli l. zmiennych = l. elementow w krotce
imie, nazwisko, wiek, srednia_ocen = student
print(f"{imie} {nazwisko} {wiek} {srednia_ocen}")
# Out:
# Jan Kowalski 29 4.5

# %%
print(f"wiek = {wiek}")
# Out:
# wiek = 29
