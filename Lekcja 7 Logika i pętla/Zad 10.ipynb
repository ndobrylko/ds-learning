# %%
even = []
czy_pierwsza = True
for i in range (2,zakres):
    for x in range (2, int(i ** (1/2))):
        if i % x == 0:
            czy_pierwsza = False
            break
        else:
            czy_pierwsza = True
            even.append(i)
    print(even)
