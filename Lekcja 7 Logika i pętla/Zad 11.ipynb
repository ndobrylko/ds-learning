# %%
sales = [1200, 1350, 1290, 1480, 1520, 1510, 1680,
1720, 1700, 1890, 1950, 2100]

growth = []

for i in range (1, len(sales)):
    diff = sales[i] - sales[i-1]
    if diff > 0:
        percent_change = (diff/sales[i-1])*100
        growth.app((i,percent_change))

print(growth)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 10
#       8     if diff > 0:
#       9         percent_change = (diff/sales[i-1])*100
# ---> 10         growth.app((i,percent_change))
#      12 print(growth)
#
# AttributeError: 'list' object has no attribute 'app'
