# %%
pesele = ["920418a2345", "85010154321", "78121698765"]
i = 0

for pesel in pesele:
    j = 0
    for i in range(11):
        if pesel[1].isdigit():
            j += 1
        if j == 11 and len(pesel) == 11 :
            print(pesel)
# Out:
# 920418a2345
# 85010154321
# 78121698765
