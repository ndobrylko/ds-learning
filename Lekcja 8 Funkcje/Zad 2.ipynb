# %%
temperatury_c = [0, 10, 20, 30, 37, 100]

def celsius_to_fahrenheit(c):
    return c * 9 / 5 + 32

def fahrenheit_to_celsius(f):
    return (f - 32) * 5 / 9

def celsius_to_kelvin(c):
    return c + 273.15

print("C\F\K")
print("-----------------")

for c in temperatury_c:
    f = celsius_to_fahrenheit(c)
    k = celsius_to_kelvin(c)
    print(f"{c}\t{f}\t{k}")
# Out:
# C\F\K
# -----------------
# 0	32.0	273.15
# 10	50.0	283.15
# 20	68.0	293.15
# 30	86.0	303.15
# 37	98.6	310.15
# 100	212.0	373.15
# <>:12: SyntaxWarning: invalid escape sequence '\F'
# <>:12: SyntaxWarning: invalid escape sequence '\F'
# /tmp/ipykernel_45917/2727561490.py:12: SyntaxWarning: invalid escape sequence '\F'
#   print("C\F\K")
