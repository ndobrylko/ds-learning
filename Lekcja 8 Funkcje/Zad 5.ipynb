# %%
produkty = [
("laptop", 2999, 4.5),
("mysz", 89, 4.2),
("klawiatura", 249, 4.8),
("monitor", 899, 4.3)
]
posortowane_produkty = sorted(produkty, key=lambda x: x[1])

print(posortowane_produkty)
# Out:
# [('mysz', 89, 4.2), ('klawiatura', 249, 4.8), ('monitor', 899, 4.3), ('laptop', 2999, 4.5)]
