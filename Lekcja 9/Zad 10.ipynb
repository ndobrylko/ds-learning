# %%
from site import check_enableusersite


class Produkt:
    def __init__(self, nazwa, cena):
        self. nazwa = nazwa
        self. cena = cena

class Zamowienie:
    def __init__ (self):
        self.produkty = produkty

    def dodaj_produkty(self, produkt):
        self.produkty.append(produkt)

    def laczna_wartosc(self):
        suma = 0
        for produkt in self.produkty:
            suma += produkt.cena
        return suma

    def __str__(self):
        for produkt in self.produkty:
            print(produkt.nazwa)
        print(self.laczna_wartosc())

lista _produktów = {"laptop: 400", "telefon: 200", "ladowarka: 20"}

my_zamowienie = Zamowienie()

for nazwa, cena in lista_produktow.items():
    produkt = Produkt(nazwa, cena)
    my_zamowienie.dodaj_produkt(produkt)

print(str(my_zamowienie))
# Out:
#   Cell In[3], line 27
#     lista _produktów = {"laptop: 400", "telefon: 200", "ladowarka: 20"}
#           ^
# SyntaxError: invalid syntax
