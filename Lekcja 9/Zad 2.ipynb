# %%
class Kalkulator:

    def dodaj (self, a, b):
        return a + b

    def odejmij (self, a,b):
        return a - b

kalkulator = Kalkulator( )

print(kalkulator.dodaj(5, 3))
print(kalkulator.odejmij(10, 4))
# Out:
# 8
# 6
