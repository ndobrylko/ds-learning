# %%
class Ksiazka:
    def __init__ (self, tytul, autor, rok_wydania, liczba_stron):
        self.tytul = tytul
        self.autor = autor
        self.rok_wydania = rok_wydania
        self.liczba_stron = liczba_stron

    def __str__(self):
        return f" '{self.tytul}' by {self.autor} ({self. rok_wydania }), {self.liczba_stron}"

    def __len__(self):
        return self.liczba_stron

moja_ksiazka = Ksiazka ("Python Programming", "John Doe", 2020, 350)
print(str(moja_ksiazka))
print(len(moja_ksiazka))
# Out:
#  'Python Programming' by John Doe (2020), 350
# 350
